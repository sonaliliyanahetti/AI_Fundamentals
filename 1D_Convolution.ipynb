# %% [markdown]
# <a href="https://colab.research.google.com/github/sonaliliyanahetti/sonaliliyanahetti/blob/main/1D_Convolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
signal = np.array([1, 1, 1, 0.5, 1, 0.5, 1, 0.5, 0.5, 0.5])

# %%
plt.stem(signal)
plt.show()

# %%
filter = np.array([-1, 1])

# %%
result = np.convolve(signal, filter, 'valid')

# %%
plt.stem(result)
plt.show()
